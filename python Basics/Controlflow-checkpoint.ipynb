# %% [markdown]
# # CONTROL FLOW STATEMENTS:
# # 1) CONDITITONAL STATEMENTS  ( if,if else & if elif else)
# # and  2) LOOPING STATEMENTS  ( for & while)
# #  CONDITIONAL STATEMENTS:-
# #==========================

# %%
# Write a program to check hether number is even ?
a= int(input("ENTER ANY NUMBER:"))
if a%2==0:
    print(a,"EVEN NUMBER")
# Out:
# ENTER ANY NUMBER: 10
# 10 EVEN NUMBER

# %%
a=int(input("ENTER ANY NUMBER"))
if a%2==0:
    print(a,"EVEN NUMBER")
else:
    print(a,"ODD NUMBER")
# Out:
# ENTER ANY NUMBER 3
# 3 ODD NUMBER

# %%
# WAP to check whether a user is eligible to vote or not ?

a=int(input("ENTER AGE"))
if a>=18:
    print(a,"is eligible to vote")
else:
    print(a, "is not eligible to vote")
# Out:
# ENTER AGE 18
# 18 is eligible to vote

# %%
# WAP to check largest between two number ( pick two inputs at runtime)?
a=int(input("Enter first number"))
b=int(input("Enter second number"))
if a>b:
      print( a , "is the largest number")
else:
      print(b, "is the largest number")
# Out:
# Enter first number 23
# Enter second number 12
# 23 is the largest number

# %%
##### WAP to find the largest number

num1=int(input("ENTER ANY NUMBER"))
num2=int(input("ENTER ANY NUMBER"))
num3=int(input("ENTER ANY NUMBER"))

if num1 > num2 and num1 > num3 :
    largest=num1
elif num2>num1 and num2>num3:
    largest=num2
else:
    largest=num3
print(largest)
# Out:
# ENTER ANY NUMBER 23
# ENTER ANY NUMBER 34
# ENTER ANY NUMBER 45
# 45

# %%
#WAP to find the highest marks?
maths=int(input("ENTER MATHS MARKS :"))
english=int(input("ENTER ENGLISH MARKS :"))
physics=int(input("ENTER PHYSICS MARKS :"))
chem=int(input("ENTER CHEM MARKS :"))

if maths>english and maths>physics and maths>chem:
    # highest=maths
    print( maths,"MATHS marks are highest")
elif english>maths and english>physics and english>chem:
    # highest=english
    print( english,"English marks are highest")
elif physics>maths and physics>english and physics>chem:
   # highest=physics
    print( physics,"Physics marks are highest")
else:
    #highest=chem
    print( chem,"chemistry marks are highest")
    
#|print(highest ," marks are highest")
# Out:
# ENTER MATHS MARKS : 39
# ENTER ENGLISH MARKS : 78
# ENTER PHYSICS MARKS : 99
# ENTER CHEM MARKS : 100
# 100 chemistry marks are highest

# %%
# QUESTION :-

mark1=float(input("ENTER MARKS:"))
mark2=float(input("ENTER MARKS:"))
mark3=float(input("ENTER MARKS:"))

total_marks=mark1+ mark2+ mark3
print( "TOTAL MARKS",total_marks)

percentage= total_marks/3
print("TOTAL PERCENTAGE ",percentage,"%")

if percentage >=90:
    print("A GRADE")
elif percentage >=80 and percentage <90:
    print("B GRADE")
elif percentage >=60 and percentage <80:
    print("C GRADE ")
elif percentage >=33 and percentage <60 :
    print("D GRADE ")
else:
    print("FAIL")
# Out:
# ENTER MARKS: 66
# ENTER MARKS: 77
# ENTER MARKS: 88
# TOTAL MARKS 231.0
# TOTAL PERCENTAGE  77.0 %
# C GRADE

# %%
# WAP to check whether a number is positive negative or zero .IF number is positive the also check is it even or odd

num=int(input("ENTER A NUMBER"))
if num>0:
    print("POSITIVE NUMBER")
    if num%2==0:
        print("EVEN NUMBER")
    else:
        print("ODD NUMBER")
elif num<0:
    print( "NEGATIVE NUMBER")
else:
    print( "NUMBER IS ZERO")
# Out:
# ENTER A NUMBER 0
# NUMBER IS ZERO

# %%
# WAP to check whether the last digit of number is divisible by 3 or not 
num=int(input("ENTER A NUMBER"))
last_digit= num % 10
if last_digit % 3==0:
    print("LAST DIGIT OF",num ," IS DIVISIBLE BY 3")
else:
    print("LAST DIGIT OF",num ," IS NOT DIVISIBLE BY 3")
# Out:
# ENTER A NUMBER 19
# LAST DIGIT OF 19  IS DIVISIBLE BY 3

# %%
#WAP to check whether a number is divisible by 5 or not?(TAKE USER INPUT)
num= int(input("ENTER A NUMBER:"))
if num%5==0:
    print("DIVISIBLE BY 5 ")
else:
    print("NOT DIVISIBLE BY 5")
# Out:
# ENTER A NUMBER: 45
# DIVISIBLE BY 5

# %%
# WAP to check whether the last two digit of number is divisible by 8 or not 
num=int(input("ENTER A NUMBER"))
last_two_digit= num % 100
print(last_two_digit)
if last_two_digit % 8==0:
    print("LASTTWO DIGIT OF",num ," IS DIVISIBLE BY 8")
else:
    print("LAST TWO DIGIT OF",num ," IS NOT DIVISIBLE BY 8")
# Out:
# ENTER A NUMBER 6756756767
# 67
# LAST TWO DIGIT OF 6756756767  IS NOT DIVISIBLE BY 8

# %%
# WAP to check whether the last digit of number is divisible by 3 or not 
num=int(input("ENTER A NUMBER"))
n=int(input("ENTER divisor"))
last_two_digit=num%100
print("LAST TWO DIGITS ARE: ",last_two_digit)

if last_two_digit % n ==0:
    print("DIVISIBLE BY ",n)
else:
    print("NOT DIVISIBLE BY ",n)
# Out:
# ENTER A NUMBER 456789
# ENTER divisor 78
# LAST TWO DIGITS ARE:  89
# NOT DIVISIBLE BY  78
